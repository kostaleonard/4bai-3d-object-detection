# %% [markdown]
# # Prediction and evaluation
#
# This notebook demonstrates the prediction of 2D and 3D bounding boxes, as well as evaluation of those boxes.
#
# **Caution: current predictions will be overwritten.**

# %%
# Import statements.
from model_2d_bounding_box import *
from dataset import TRAIN_IMAGE_DIR, LABEL_DIR, TRAIN_KEY, VAL_KEY, TEST_KEY, \
    PARTITION_LABEL_DIR, get_train_only_kitti_partition, get_labels, \
    create_partition_label_dirs
from shutil import rmtree
import os
import time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4591680b4e84> in <module>
#       1 # Import statements.
# ----> 2 from model_2d_bounding_box import *
#       3 from dataset import TRAIN_IMAGE_DIR, LABEL_DIR, TRAIN_KEY, VAL_KEY, TEST_KEY, \
#       4     PARTITION_LABEL_DIR, get_train_only_kitti_partition, get_labels, \
#       5     create_partition_label_dirs
#
# ~/Documents/ML/Courses/FourthBrain/Project/4bai-3d-object-detection/notebooks/model_2d_bounding_box.py in <module>
#     163     sess: tf.Session,
#     164     image_file: str,
# --> 165     verbose: bool = False) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
#     166     """Runs the YOLO graph stored in the session on the image.
#     167     :param yolo_model: The YOLO model.
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
# TODO delete. This is because the 2D model code isn't merged yet,
# so it's not TF 2.x compatible.
from dataset import TRAIN_IMAGE_DIR, LABEL_DIR, TRAIN_KEY, VAL_KEY, TEST_KEY, \
    PARTITION_LABEL_DIR, get_train_only_kitti_partition, get_labels, \
    create_partition_label_dirs
from shutil import rmtree
import os
import time
partition = get_train_only_kitti_partition(TRAIN_IMAGE_DIR)
labels = get_labels(LABEL_DIR)

# %%
# Global constants.
TRAIN_3D_PREDICT_DIR = os.path.join('..', 'data', 'predictions', '3d_boxes',
                                    'train')
VAL_3D_PREDICT_DIR = os.path.join('..', 'data', 'predictions', '3d_boxes',
                                  'val')
TEST_3D_PREDICT_DIR = os.path.join('..', 'data', 'predictions', '3d_boxes',
                                   'test')

# %% [markdown]
# # 2D bounding box prediction
#
# In this section, we will run 2D prediction.
#
# **Caution: overwrites previous predictions.**

# %%
rmtree(TRAIN_PREDICT_DIR)
rmtree(VAL_PREDICT_DIR)
rmtree(TEST_PREDICT_DIR)
os.mkdir(TRAIN_PREDICT_DIR)
os.mkdir(VAL_PREDICT_DIR)
os.mkdir(TEST_PREDICT_DIR)

# %%
sess = get_session()
yolo_model = get_yolo_model(YOLO_MODEL_PATH)
partition = get_train_only_kitti_partition(TRAIN_IMAGE_DIR)
labels = get_labels(LABEL_DIR)
# Out:
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /Users/kian/Desktop/floydhub/yolo-03-oct/YAD2K/yad2k/models/keras_yolo.py:32: The name tf.space_to_depth is deprecated. Please use tf.compat.v1.space_to_depth instead.
# /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ### Train set

# %%
kitti_train_predictions = predict_on_list(yolo_model, sess, TRAIN_IMAGE_DIR,
                                          partition[TRAIN_KEY],
                                          max_images=10)
write_predictions_on_dir(kitti_train_predictions, TRAIN_IMAGE_DIR,
                         TRAIN_PREDICT_DIR, label_dir=LABEL_DIR)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/leo/Documents/ML/Courses/FourthBrain/Project/4bai-3d-object-detection/notebooks/model_2d_bounding_box.py:123: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]

# %% [markdown]
# ### Val set

# %%
kitti_val_predictions = predict_on_list(yolo_model, sess, TRAIN_IMAGE_DIR,
                                        partition[VAL_KEY],
                                        max_images=10)
write_predictions_on_dir(kitti_val_predictions, TRAIN_IMAGE_DIR,
                         VAL_PREDICT_DIR, label_dir=LABEL_DIR)
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]

# %% [markdown]
# ### Test set

# %%
kitti_test_predictions = predict_on_list(yolo_model, sess, TRAIN_IMAGE_DIR,
                                        partition[TEST_KEY],
                                        max_images=10)
write_predictions_on_dir(kitti_test_predictions, TRAIN_IMAGE_DIR,
                         TEST_PREDICT_DIR, label_dir=LABEL_DIR)
# Out:
# 100%|██████████| 10/10 [00:15<00:00,  1.59s/it]

# %% [markdown]
# # 3D bounding box prediction
#
# In this section, we will run 3D prediction on the 2D bounding boxes from the last step.

# %% [markdown]
# ### Train set

# %%
rmtree(TRAIN_3D_PREDICT_DIR)
rmtree(VAL_3D_PREDICT_DIR)
rmtree(TEST_3D_PREDICT_DIR)
os.mkdir(TRAIN_3D_PREDICT_DIR)
os.mkdir(VAL_3D_PREDICT_DIR)
os.mkdir(TEST_3D_PREDICT_DIR)

# %%
# !cd .. && make predict_on_yolo_train && cd notebooks
# Out:
# python src/main/main.py --mode test --gpu -1 --image data/KITTI/data_object_image_2/training/image_2/ --box2d data/predictions/2d_boxes/train/ --model model/demo_model --output data/predictions/3d_boxes/train/
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From src/main/main.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From src/main/main.py:110: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From src/main/main.py:122: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From src/main/main.py:134: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From src/main/main.py:141: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From src/main/main.py:216: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From src/main/main.py:218: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-01-11 09:59:12.802398: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-01-11 09:59:12.812526: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fedd09093c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-11 09:59:12.812554: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From src/main/main.py:221: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From src/main/main.py:225: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# 2021-01-11 09:59:13.105190: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at save_restore_v2_ops.cc:184 : Out of range: Read less bytes than requested
# Traceback (most recent call last):
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.OutOfRangeError: Read less bytes than requested
# 	 [[{{node save/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/main/main.py", line 319, in <module>
#     test(args.model, args.image, args.box2d, args.output)
#   File "src/main/main.py", line 226, in test
#     saver.restore(sess, model)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 1290, in restore
#     {self.saver_def.filename_tensor_name: save_path})
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1384, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.OutOfRangeError: Read less bytes than requested
# 	 [[node save/RestoreV2 (defined at /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py:1748) ]]
#
# Original stack trace for 'save/RestoreV2':
#   File "src/main/main.py", line 319, in <module>
#     test(args.model, args.image, args.box2d, args.output)
#   File "src/main/main.py", line 225, in test
#     saver = tf.train.Saver()
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 828, in __init__
#     self.build()
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
# make: *** [predict_on_yolo_train] Error 1

# %% [markdown]
# ### Val set

# %%
# !cd .. && make predict_on_yolo_val && cd notebooks
# Out:
# python src/main/main.py --mode test --gpu -1 --image data/KITTI/data_object_image_2/training/image_2/ --box2d data/predictions/2d_boxes/val/ --model model/model-1 --output data/predictions/3d_boxes/val/
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From src/main/main.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From src/main/main.py:110: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From src/main/main.py:122: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From src/main/main.py:134: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From src/main/main.py:141: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From src/main/main.py:216: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From src/main/main.py:218: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-01-06 14:33:58.550914: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-01-06 14:33:58.561822: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd5542b0fe0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-06 14:33:58.561838: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From src/main/main.py:221: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From src/main/main.py:225: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Loaded 7481 test images
# data/KITTI/data_object_image_2/training/image_2/001408.png
# data/KITTI/data_object_image_2/training/image_2/001616.png
# data/KITTI/data_object_image_2/training/image_2/001793.png
# data/KITTI/data_object_image_2/training/image_2/003825.png
# data/KITTI/data_object_image_2/training/image_2/005036.png
# data/KITTI/data_object_image_2/training/image_2/005740.png
# data/KITTI/data_object_image_2/training/image_2/006071.png
# data/KITTI/data_object_image_2/training/image_2/006167.png
# data/KITTI/data_object_image_2/training/image_2/006665.png
# data/KITTI/data_object_image_2/training/image_2/007338.png

# %% [markdown]
# ### Test set

# %%
# !cd .. && make predict_on_yolo_test && cd notebooks
# Out:
# python src/main/main.py --mode test --gpu -1 --image data/KITTI/data_object_image_2/training/image_2/ --box2d data/predictions/2d_boxes/test/ --model model/model-1 --output data/predictions/3d_boxes/test/
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From src/main/main.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From src/main/main.py:110: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From src/main/main.py:122: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From src/main/main.py:134: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From src/main/main.py:141: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From src/main/main.py:216: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From src/main/main.py:218: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-01-06 14:34:08.223817: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-01-06 14:34:08.237288: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc8cd4dca70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-06 14:34:08.237305: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From src/main/main.py:221: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From src/main/main.py:225: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Loaded 7481 test images
# data/KITTI/data_object_image_2/training/image_2/000466.png
# data/KITTI/data_object_image_2/training/image_2/000751.png
# data/KITTI/data_object_image_2/training/image_2/001605.png
# data/KITTI/data_object_image_2/training/image_2/002081.png
# data/KITTI/data_object_image_2/training/image_2/002508.png
# data/KITTI/data_object_image_2/training/image_2/003068.png
# data/KITTI/data_object_image_2/training/image_2/003690.png
# data/KITTI/data_object_image_2/training/image_2/004043.png
# data/KITTI/data_object_image_2/training/image_2/006632.png
# data/KITTI/data_object_image_2/training/image_2/007106.png

# %% [markdown]
# # Evaluation: 2D boxes
#
# In this section, we will evaluate our 2D bounding box predictions. We report the mean IoU achieved over all predicted bounding boxes.

# %% [markdown]
# ### Train set

# %%
get_mean_iou(kitti_train_predictions, labels, TRAIN_IMAGE_DIR)
# Out:
# 0.05686985652273623

# %% [markdown]
# ### Val set

# %%
get_mean_iou(kitti_val_predictions, labels, TRAIN_IMAGE_DIR)
# Out:
# 0.06489563326910827

# %% [markdown]
# ### Test set

# %%
get_mean_iou(kitti_test_predictions, labels, TRAIN_IMAGE_DIR)
# Out:
# 0.07199652340346975

# %% [markdown]
# # Evaluation: 3D boxes based on 2D predictions
#
# In this section, we will evaluate our 3D bounding box predictions based on our 2D bounding box predictions.
#
# ## Interpretation of output
#
# The output of the evaluation cpp file is a little cryptic. It is divided into 2 sections.
#
# 1. Object detection AP: Reports the average precision for object detection on the easy, medium, and hard levels, respectively. The output number in each category represents the percent of objects correctly identified in that class, based on the minimum IoU requirements to consider the object detected. The IoU threshold increases from easy to medium to hard.
# 1. 3D bounding box AP: Reports the average precision for 3D bounding boxes on the easy, medium, and hard levels, respectively. The output number in each category represents the mean average precision achieved on that class.

# %% [markdown]
# ### Train set

# %%
# !cd .. && make eval_train_predictions && cd notebooks
# Out:
# g++ -O3 -DNDEBUG -o ./kitti_eval/evaluate_object_3d_offline ./kitti_eval/evaluate_object_3d_offline.cpp
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:27:1: warning: CAUTION:
#       Boost.Geometry in Boost 1.73 deprecates support for C++03 and will require
#       C++14 from Boost 1.75 onwards. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Boost.Geometry in Boost 1.73 deprecates s...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:53:2: note: expanded from here
#  message("CAUTION: Boost.Geometry in Boost 1.73 deprecates support for C...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:28:1: warning: CAUTION: Define
#       BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:56:2: note: expanded from here
#  message("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING t...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:99:1: warning: CAUTION: One
#       or more C++11 features were found to be unavailable [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: One or more C++11 features were found to ...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:59:2: note: expanded from here
#  message("CAUTION: One or more C++11 features were found to be unavailable")
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:100:1: warning: CAUTION:
#       Compiling Boost.Math in pre-C++11 conformance modes is now deprecated and
#       will be removed from March 2021. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Compiling Boost.Math in pre-C++11 conform...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:62:2: note: expanded from here
#  message("CAUTION: Compiling Boost.Math in pre-C++11 conformance modes i...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:101:1: warning: CAUTION:
#       Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_W...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:65:2: note: expanded from here
#  message("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to su...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:102:1: warning: CAUTION: This
#       message was generated due to the define: BOOST_NO_CXX11_NOEXCEPT
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: This message was generated due to the def...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:68:2: note: expanded from here
#  message("CAUTION: This message was generated due to the define: " "BOOS...
#  ^
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: warning: using the result of
#       an assignment as a condition without parentheses [-Wparentheses]
#         while (entity = readdir(dir)) {
#                ~~~~~~~^~~~~~~~~~~~~~
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: place parentheses
#       around the assignment to silence this warning
#         while (entity = readdir(dir)) {
#                       ^
#                (                    )
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: use '==' to turn this
#       assignment into an equality comparison
#         while (entity = readdir(dir)) {
#                       ^
#                       ==
# 7 warnings generated.
# ./kitti_eval/evaluate_object_3d_offline data/KITTI/training/label_2/ data/predictions/3d_boxes/train/
# Thank you for participating in our evaluation!
# Loading detections...
# number of files for evaluation: 202
#   done.
# save data/predictions/3d_boxes/train//plot/car_detection.txt
# car_detection AP: 100.000000 100.000000 100.000000
# save data/predictions/3d_boxes/train//plot/car_orientation.txt
# car_orientation AP: 69.453743 64.508286 63.121750
# save data/predictions/3d_boxes/train//plot/pedestrian_detection.txt
# pedestrian_detection AP: 90.909096 100.000000 100.000000
# save data/predictions/3d_boxes/train//plot/pedestrian_orientation.txt
# pedestrian_orientation AP: 62.988369 65.720306 63.185764
# save data/predictions/3d_boxes/train//plot/cyclist_detection.txt
# cyclist_detection AP: 36.363636 72.727272 81.818184
# save data/predictions/3d_boxes/train//plot/cyclist_orientation.txt
# cyclist_orientation AP: 17.926924 39.556091 43.538597
# save data/predictions/3d_boxes/train//plot/car_detection_ground.txt
# car_detection_ground AP: 56.941391 59.648079 62.412731
# save data/predictions/3d_boxes/train//plot/pedestrian_detection_ground.txt
# pedestrian_detection_ground AP: 88.537544 98.711525 89.862656
# save data/predictions/3d_boxes/train//plot/cyclist_detection_ground.txt
# cyclist_detection_ground AP: 31.550800 44.819164 52.762920
# Eval 3D bounding boxes
# save data/predictions/3d_boxes/train//plot/car_detection_3d.txt
# car_detection_3d AP: 41.454174 50.639164 48.357506
# save data/predictions/3d_boxes/train//plot/pedestrian_detection_3d.txt
# pedestrian_detection_3d AP: 88.134979 89.537315 89.678154
# save data/predictions/3d_boxes/train//plot/cyclist_detection_3d.txt
# cyclist_detection_3d AP: 31.550800 44.819164 52.762920
# Your evaluation results are available at:
# data/predictions/3d_boxes/train/

# %% [markdown]
# ### Val set

# %%
# !cd .. && make eval_val_predictions && cd notebooks
# Out:
# g++ -O3 -DNDEBUG -o ./kitti_eval/evaluate_object_3d_offline ./kitti_eval/evaluate_object_3d_offline.cpp
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:27:1: warning: CAUTION:
#       Boost.Geometry in Boost 1.73 deprecates support for C++03 and will require
#       C++14 from Boost 1.75 onwards. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Boost.Geometry in Boost 1.73 deprecates s...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:53:2: note: expanded from here
#  message("CAUTION: Boost.Geometry in Boost 1.73 deprecates support for C...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:28:1: warning: CAUTION: Define
#       BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:56:2: note: expanded from here
#  message("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING t...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:99:1: warning: CAUTION: One
#       or more C++11 features were found to be unavailable [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: One or more C++11 features were found to ...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:59:2: note: expanded from here
#  message("CAUTION: One or more C++11 features were found to be unavailable")
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:100:1: warning: CAUTION:
#       Compiling Boost.Math in pre-C++11 conformance modes is now deprecated and
#       will be removed from March 2021. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Compiling Boost.Math in pre-C++11 conform...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:62:2: note: expanded from here
#  message("CAUTION: Compiling Boost.Math in pre-C++11 conformance modes i...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:101:1: warning: CAUTION:
#       Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_W...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:65:2: note: expanded from here
#  message("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to su...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:102:1: warning: CAUTION: This
#       message was generated due to the define: BOOST_NO_CXX11_NOEXCEPT
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: This message was generated due to the def...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:68:2: note: expanded from here
#  message("CAUTION: This message was generated due to the define: " "BOOS...
#  ^
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: warning: using the result of
#       an assignment as a condition without parentheses [-Wparentheses]
#         while (entity = readdir(dir)) {
#                ~~~~~~~^~~~~~~~~~~~~~
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: place parentheses
#       around the assignment to silence this warning
#         while (entity = readdir(dir)) {
#                       ^
#                (                    )
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: use '==' to turn this
#       assignment into an equality comparison
#         while (entity = readdir(dir)) {
#                       ^
#                       ==
# 7 warnings generated.
# ./kitti_eval/evaluate_object_3d_offline data/KITTI/training/label_2/ data/predictions/3d_boxes/val/
# Thank you for participating in our evaluation!
# Loading detections...
# number of files for evaluation: 10
#   done.
# save data/predictions/3d_boxes/val//plot/car_detection.txt
# car_detection AP: 16.883118 15.584415 15.584415
# save data/predictions/3d_boxes/val//plot/car_orientation.txt
# car_orientation AP: 16.842785 15.521063 15.521063
# save data/predictions/3d_boxes/val//plot/car_detection_ground.txt
# car_detection_ground AP: 17.171717 26.515154 26.573425
# Eval 3D bounding boxes
# save data/predictions/3d_boxes/val//plot/car_detection_3d.txt
# car_detection_3d AP: 17.171717 26.515154 26.573425
# Your evaluation results are available at:
# data/predictions/3d_boxes/val/

# %% [markdown]
# ### Test set

# %%
# !cd .. && make eval_test_predictions && cd notebooks
# Out:
# g++ -O3 -DNDEBUG -o ./kitti_eval/evaluate_object_3d_offline ./kitti_eval/evaluate_object_3d_offline.cpp
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:27:1: warning: CAUTION:
#       Boost.Geometry in Boost 1.73 deprecates support for C++03 and will require
#       C++14 from Boost 1.75 onwards. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Boost.Geometry in Boost 1.73 deprecates s...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:53:2: note: expanded from here
#  message("CAUTION: Boost.Geometry in Boost 1.73 deprecates support for C...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# /usr/local/include/boost/geometry/geometry.hpp:28:1: warning: CAUTION: Define
#       BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:56:2: note: expanded from here
#  message("CAUTION: Define BOOST_GEOMETRY_DISABLE_DEPRECATED_03_WARNING t...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:99:1: warning: CAUTION: One
#       or more C++11 features were found to be unavailable [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: One or more C++11 features were found to ...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:59:2: note: expanded from here
#  message("CAUTION: One or more C++11 features were found to be unavailable")
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:100:1: warning: CAUTION:
#       Compiling Boost.Math in pre-C++11 conformance modes is now deprecated and
#       will be removed from March 2021. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Compiling Boost.Math in pre-C++11 conform...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:62:2: note: expanded from here
#  message("CAUTION: Compiling Boost.Math in pre-C++11 conformance modes i...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:101:1: warning: CAUTION:
#       Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to suppress this message.
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_W...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:65:2: note: expanded from here
#  message("CAUTION: Define BOOST_MATH_DISABLE_DEPRECATED_03_WARNING to su...
#  ^
# In file included from ./kitti_eval/evaluate_object_3d_offline.cpp:15:
# In file included from /usr/local/include/boost/geometry.hpp:17:
# In file included from /usr/local/include/boost/geometry/geometry.hpp:51:
# In file included from /usr/local/include/boost/geometry/core/radian_access.hpp:33:
# In file included from /usr/local/include/boost/geometry/util/math.hpp:29:
# In file included from /usr/local/include/boost/math/constants/constants.hpp:11:
# /usr/local/include/boost/math/tools/cxx03_warn.hpp:102:1: warning: CAUTION: This
#       message was generated due to the define: BOOST_NO_CXX11_NOEXCEPT
#       [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE("CAUTION: This message was generated due to the def...
# ^
# /usr/local/include/boost/config/pragma_message.hpp:24:34: note: expanded from
#       macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:68:2: note: expanded from here
#  message("CAUTION: This message was generated due to the define: " "BOOS...
#  ^
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: warning: using the result of
#       an assignment as a condition without parentheses [-Wparentheses]
#         while (entity = readdir(dir)) {
#                ~~~~~~~^~~~~~~~~~~~~~
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: place parentheses
#       around the assignment to silence this warning
#         while (entity = readdir(dir)) {
#                       ^
#                (                    )
# ./kitti_eval/evaluate_object_3d_offline.cpp:782:23: note: use '==' to turn this
#       assignment into an equality comparison
#         while (entity = readdir(dir)) {
#                       ^
#                       ==
# 7 warnings generated.
# ./kitti_eval/evaluate_object_3d_offline data/KITTI/training/label_2/ data/predictions/3d_boxes/test/
# Thank you for participating in our evaluation!
# Loading detections...
# number of files for evaluation: 10
#   done.
# save data/predictions/3d_boxes/test//plot/car_detection.txt
# car_detection AP: 7.272727 24.545456 25.619835
# save data/predictions/3d_boxes/test//plot/car_orientation.txt
# car_orientation AP: 6.776002 21.283100 22.478510
# save data/predictions/3d_boxes/test//plot/pedestrian_detection.txt
# pedestrian_detection AP: 0.000000 0.000000 0.000000
# save data/predictions/3d_boxes/test//plot/pedestrian_orientation.txt
# pedestrian_orientation AP: 0.000000 0.000000 0.000000
# save data/predictions/3d_boxes/test//plot/car_detection_ground.txt
# car_detection_ground AP: 3.030303 8.373206 8.373206
# save data/predictions/3d_boxes/test//plot/pedestrian_detection_ground.txt
# pedestrian_detection_ground AP: 0.000000 0.000000 0.000000
# Eval 3D bounding boxes
# save data/predictions/3d_boxes/test//plot/car_detection_3d.txt
# car_detection_3d AP: 3.030303 8.333334 8.333334
# save data/predictions/3d_boxes/test//plot/pedestrian_detection_3d.txt
# pedestrian_detection_3d AP: 0.000000 0.000000 0.000000
# Your evaluation results are available at:
# data/predictions/3d_boxes/test/

# %% [markdown]
# # Evaluation: 3D boxes based on 2D ground truth
#
# In this section, we will evaluate our 3D bounding box predictions based on the 2D ground truth labels.
#
# **Caution: overwrites current predictions.**

# %%
create_partition_label_dirs(partition, LABEL_DIR, PARTITION_LABEL_DIR)
rmtree(TRAIN_3D_PREDICT_DIR)
rmtree(VAL_3D_PREDICT_DIR)
rmtree(TEST_3D_PREDICT_DIR)
os.mkdir(TRAIN_3D_PREDICT_DIR)
os.mkdir(VAL_3D_PREDICT_DIR)
os.mkdir(TEST_3D_PREDICT_DIR)

# %% [markdown]
# ### Train set

# %%
# !cd .. && make predict_on_ground_truth_partition_train && cd notebooks
# Out:
# python src/main/main.py --mode test --gpu -1 --image data/KITTI/data_object_image_2/training/image_2/ --box2d data/KITTI/training/label_2_partitioned/train/ --model model/model_100_epochs_29JAN.h5 --output data/predictions/3d_boxes/train/
# /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:1059: UserWarning: model_3d_bounding_box is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)
# 2021-01-29 12:38:59.908343: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-29 12:38:59.908579: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded 7481 test images
# data/KITTI/data_object_image_2/training/image_2/000000.png
# 2021-01-29 12:39:01.135945: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# data/KITTI/data_object_image_2/training/image_2/000001.png
# data/KITTI/data_object_image_2/training/image_2/000002.png
# data/KITTI/data_object_image_2/training/image_2/000005.png
# data/KITTI/data_object_image_2/training/image_2/000006.png
# data/KITTI/data_object_image_2/training/image_2/000007.png
# data/KITTI/data_object_image_2/training/image_2/000009.png
# data/KITTI/data_object_image_2/training/image_2/000010.png
# data/KITTI/data_object_image_2/training/image_2/000011.png
# data/KITTI/data_object_image_2/training/image_2/000012.png
# data/KITTI/data_object_image_2/training/image_2/000013.png
# data/KITTI/data_object_image_2/training/image_2/000015.png
# data/KITTI/data_object_image_2/training/image_2/000016.png
# data/KITTI/data_object_image_2/training/image_2/000017.png
# data/KITTI/data_object_image_2/training/image_2/000021.png
# data/KITTI/data_object_image_2/training/image_2/000022.png
# data/KITTI/data_object_image_2/training/image_2/000023.png
# data/KITTI/data_object_image_2/training/image_2/000024.png
# data/KITTI/data_object_image_2/training/image_2/000025.png
# data/KITTI/data_object_image_2/training/image_2/000028.png
# data/KITTI/data_object_image_2/training/image_2/000029.png
# data/KITTI/data_object_image_2/training/image_2/000030.png
# data/KITTI/data_object_image_2/training/image_2/000035.png
# data/KITTI/data_object_image_2/training/image_2/000036.png
# data/KITTI/data_object_image_2/training/image_2/000037.png
# data/KITTI/data_object_image_2/training/image_2/000038.png
# data/KITTI/data_object_image_2/training/image_2/000039.png
# data/KITTI/data_object_image_2/training/image_2/000040.png
# data/KITTI/data_object_image_2/training/image_2/000042.png
# data/KITTI/data_object_image_2/training/image_2/000043.png
# data/KITTI/data_object_image_2/training/image_2/000044.png
# data/KITTI/data_object_image_2/training/image_2/000047.png
# data/KITTI/data_object_image_2/training/image_2/000048.png
# data/KITTI/data_object_image_2/training/image_2/000049.png
# data/KITTI/data_object_image_2/training/image_2/003589.png
# data/KITTI/data_object_image_2/training/image_2/003590.png
# data/KITTI/data_object_image_2/training/image_2/003591.png
# data/KITTI/data_object_image_2/training/image_2/003594.png
# data/KITTI/data_object_image_2/training/image_2/003595.png
# data/KITTI/data_object_image_2/training/image_2/003597.png
# data/KITTI/data_object_image_2/training/image_2/003598.png
# data/KITTI/data_object_image_2/training/image_2/003605.png
# data/KITTI/data_object_image_2/training/image_2/003606.png
# data/KITTI/data_object_image_2/training/image_2/003607.png
# data/KITTI/data_object_image_2/training/image_2/003608.png
# data/KITTI/data_object_image_2/training/image_2/003609.png
# data/KITTI/data_object_image_2/training/image_2/003610.png
# data/KITTI/data_object_image_2/training/image_2/003612.png
# data/KITTI/data_object_image_2/training/image_2/003613.png
# data/KITTI/data_object_image_2/training/image_2/003614.png
# data/KITTI/data_object_image_2/training/image_2/003615.png
# data/KITTI/data_object_image_2/training/image_2/003617.png
# data/KITTI/data_object_image_2/training/image_2/003618.png
# data/KITTI/data_object_image_2/training/image_2/003620.png
# data/KITTI/data_object_image_2/training/image_2/003621.png
# data/KITTI/data_object_image_2/training/image_2/003622.png
# data/KITTI/data_object_image_2/training/image_2/003627.png
# data/KITTI/data_object_image_2/training/image_2/003628.png
# data/KITTI/data_object_image_2/training/image_2/003630.png
# data/KITTI/data_object_image_2/training/image_2/003631.png
# data/KITTI/data_object_image_2/training/image_2/003633.png
# data/KITTI/data_object_image_2/training/image_2/003636.png
# data/KITTI/data_object_image_2/training/image_2/003637.png
# data/KITTI/data_object_image_2/training/image_2/003638.png
# data/KITTI/data_object_image_2/training/image_2/003639.png
# data/KITTI/data_object_image_2/training/image_2/003640.png
# data/KITTI/data_object_image_2/training/image_2/003643.png
# data/KITTI/data_object_image_2/training/image_2/003644.png
# data/KITTI/data_object_image_2/training/image_2/003645.png
# data/KITTI/data_object_image_2/training/image_2/003646.png
# data/KITTI/data_object_image_2/training/image_2/003647.png
# data/KITTI/data_object_image_2/training/image_2/003648.png
# data/KITTI/data_object_image_2/training/image_2/003650.png
# data/KITTI/data_object_image_2/training/image_2/003653.png
# data/KITTI/data_object_image_2/training/image_2/003654.png
# data/KITTI/data_object_image_2/training/image_2/003656.png
# data/KITTI/data_object_image_2/training/image_2/003657.png
# data/KITTI/data_object_image_2/training/image_2/003658.png

# %%
# !cd .. && make eval_train_predictions && cd notebooks

# %% [markdown]
# ### Val set

# %%
# !cd .. && make predict_on_ground_truth_partition_val && cd notebooks

# %%
# !cd .. && make eval_val_predictions && cd notebooks

# %% [markdown]
# ### Test set

# %%
# !cd .. && make predict_on_ground_truth_partition_test && cd notebooks

# %%
# !cd .. && make eval_test_predictions && cd notebooks

# %% [markdown]
# # Evaluation: frames per second (FPS)
#
# In this section, we will test the speed of our model's predictions in frames per second. Runs on images from the test set.
#
# **Caution: overwrites previous predictions.**

# %%
rmtree(TRAIN_PREDICT_DIR)
rmtree(VAL_PREDICT_DIR)
rmtree(TEST_PREDICT_DIR)
os.mkdir(TRAIN_PREDICT_DIR)
os.mkdir(VAL_PREDICT_DIR)
os.mkdir(TEST_PREDICT_DIR)
create_partition_label_dirs(partition, LABEL_DIR, PARTITION_LABEL_DIR)
rmtree(TRAIN_3D_PREDICT_DIR)
rmtree(VAL_3D_PREDICT_DIR)
rmtree(TEST_3D_PREDICT_DIR)
os.mkdir(TRAIN_3D_PREDICT_DIR)
os.mkdir(VAL_3D_PREDICT_DIR)
os.mkdir(TEST_3D_PREDICT_DIR)
NUM_EXAMPLES = 10

# %% [markdown]
# ### 2D model

# %%
start = time.time()
kitti_test_predictions = predict_on_list(yolo_model, sess, TRAIN_IMAGE_DIR,
                                        partition[TEST_KEY],
                                        max_images=NUM_EXAMPLES)
end = time.time()
write_predictions_on_dir(kitti_test_predictions, TRAIN_IMAGE_DIR,
                         TEST_PREDICT_DIR, label_dir=LABEL_DIR)
predict_2d_time = end - start
print('Total 2D prediction time: {0} s'.format(predict_2d_time))
print('2D prediction FPS ({0} examples): {1}'.format(
    NUM_EXAMPLES, NUM_EXAMPLES / predict_2d_time))
# Out:
# 100%|██████████| 10/10 [00:38<00:00,  3.88s/it]
# Total 2D prediction time: 38.84774875640869 s
# 2D prediction FPS (10 examples): 0.25741517385483775

# %% [markdown]
# ### 3D model

# %%
start = time.time()
# !cd .. && make predict_on_yolo_test && cd notebooks
end = time.time()
predict_3d_time = end - start
print('Total 3D prediction time: {0} s'.format(predict_3d_time))
print('3D prediction FPS ({0} examples): {1}'.format(
    NUM_EXAMPLES, NUM_EXAMPLES / predict_3d_time))
# Out:
# python src/main/main.py --mode test --gpu -1 --image data/KITTI/data_object_image_2/training/image_2/ --box2d data/predictions/2d_boxes/test/ --model model/model-1 --output data/predictions/3d_boxes/test/
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From src/main/main.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From src/main/main.py:110: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From /Users/leo/anaconda3/envs/4bai-project/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From src/main/main.py:122: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From src/main/main.py:134: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From src/main/main.py:141: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From src/main/main.py:216: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From src/main/main.py:218: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-01-07 10:54:15.452298: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-01-07 10:54:15.462093: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc2a9ad9b10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-07 10:54:15.462124: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From src/main/main.py:221: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From src/main/main.py:225: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Loaded 7481 test images
# data/KITTI/data_object_image_2/training/image_2/000466.png
# data/KITTI/data_object_image_2/training/image_2/000751.png
# data/KITTI/data_object_image_2/training/image_2/001605.png
# data/KITTI/data_object_image_2/training/image_2/002081.png
# data/KITTI/data_object_image_2/training/image_2/002508.png
# data/KITTI/data_object_image_2/training/image_2/003068.png
# data/KITTI/data_object_image_2/training/image_2/003690.png
# data/KITTI/data_object_image_2/training/image_2/004043.png
# data/KITTI/data_object_image_2/training/image_2/006632.png
# data/KITTI/data_object_image_2/training/image_2/007106.png
# Total 3D prediction time: 6.666807174682617 s
# 3D prediction FPS (10 examples): 1.4999683863627065

# %% [markdown]
# ### Complete pipeline (2D prediction plus 3D prediction)

# %%
predict_total_time = predict_2d_time + predict_3d_time
print('Total 2D + 3D prediction time: {0} s'.format(predict_total_time))
print('2D + 3D prediction FPS ({0} examples): {1}'.format(
    NUM_EXAMPLES, NUM_EXAMPLES / predict_total_time))
# Out:
# Total 2D + 3D prediction time: 45.51455593109131 s
# 2D + 3D prediction FPS (10 examples): 0.2197099322498043
